# %%
def func(x):
    a = ""
    try:
        for element in reversed(range(x +1)):
            for i in reversed(range(element)):
                t =i + 1 
                a+= f"{str(t)} "
            print(a)
            a = ""
    except:
        print(f"Enter valid value")
        
func(5)
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1
